# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = np.linspace(0.01, 0.02, 400)
x1 = np.pi/a
x2 = np.pi*2/a
x3 = np.pi*3/a

# %%
plt.plot(a, x1, label='k=1')
plt.plot(a, x2, label='k=2')
plt.plot(a, x3, label='k=3')
plt.legend()
